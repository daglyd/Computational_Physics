# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Data/problem_6/iterations_N.csv")

# %%
df.plot(x='N',figsize=(16,8))
plt.savefig('../Figures/problem_6_iteratios.pdf')
